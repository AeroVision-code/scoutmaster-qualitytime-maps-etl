# %% [markdown]
# ## Layer types

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')

# Scoutmaster API - Init
SM_API = ScoutMasterAPI()
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://api.scoutmaster.nl/v2/

# %%
output_folder = "../data/output/"

# %%
SM_API.output_format = 'df'
df_layer_types = SM_API.layer_types()
df_layer_types
# Out:
#                                       id               name    type  \
# 0   0685e79a-d5ca-43f8-a634-6068bdbacfab           Biomassa   index
# 1   502ff6f2-d14a-4e4d-a54c-ba14b1f84387           Stikstof   index
# 2   d7ba4f2e-38b9-4fe2-a598-d552b8327c0b                DSM   index
# 3   9fa20d5b-e46f-424f-b16f-0200bea8c510           Bijgroei   index
# 4   d7ba4f2e-38b9-4fe2-a598-d552b8327c0b                DSM   index
# ..                                   ...                ...     ...
# 79  a976faf7-fb95-40c2-a7fe-973242e5aead          SoilZones   index
# 80  4d787c38-1bc0-4948-864e-684f7d291bcd                NIR    band
# 81  24d4a504-8f95-46d7-b199-f79bd1965dd0  SampleLocations 4  vector
# 82  389b682a-facc-467b-a387-e75b6679b7af   Normalized Green   index
# 83  e86e7b7b-444c-4921-9835-9b7e13846567               NDRE   index
#
#    abbreviation            group_name  \
# 0          WDVI  Vegetation maps (HD)
# 1        CI-red  Vegetation maps (HD)
# 2           DTM        Elevation maps
# 3    Add-growth  Vegetation maps (HD)
# 4           DTM        Elevation maps
# ..          ...                   ...
# 79        ZONES             soilzones
# 80          NIR             soilzones
# 81       POINTS             soilzones
# 82           NG             soilzones
# 83         None             soilzones
#
#                                          layer_source  \
# 0   {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 1   {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 2   {'id': '7dfe647f-3caa-4146-8ef3-dcfb5b87a634',...
# 3   {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 4   {'id': '7dfe647f-3caa-4146-8ef3-dcfb5b87a634',...
# ..                                                ...
# 79  {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 80  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 81  {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 82  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 83  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
#
#                                         preview_image
# 0   https://bioscope-products.s3.eu-central-1.amaz...
# 1   https://bioscope-products.s3.eu-central-1.amaz...
# 2   https://bioscope-products.s3.eu-central-1.amaz...
# 3   https://bioscope-products.s3.eu-central-1.amaz...
# 4   https://bioscope-products.s3.eu-central-1.amaz...
# ..                                                ...
# 79  https://bioscope-products.s3.eu-central-1.amaz...
# 80  https://bioscope-products.s3.eu-central-1.amaz...
# 81  https://bioscope-products.s3.eu-central-1.amaz...
# 82  https://bioscope-products.s3.eu-central-1.amaz...
# 83  https://bioscope-products.s3.eu-central-1.amaz...
#
# [84 rows x 7 columns]

# %%
from IPython.display import Image, HTML, display

def show_layer_previews(df, limit=10):
    rows = []
    for i, row in df.head(limit).iterrows():
        print(row["preview_image"])
        rows.append(f"""
        <div style="display:inline-block; margin:10px; text-align:center;">
            <img src="{row['preview_image']}" width="150"><br>
            <b>{row['name']}</b><br>
            <small>{row['abbreviation']}</small>
        </div>
        """)
    display(HTML("".join(rows)))

show_layer_previews(df_layer_types)
# Out:
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/PLanet_WDVI.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=bfe80ce502fec4b9ca71b7761e992709f472abc9320965be515f5ff6401dfacc&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_CI-Red.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=40aa873c70bfc5b6c791fabb92ed428672571d6008f19716f461f6510ff214af&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=8c3a7743b1bd8852c12450937f052fc6d5135ce2767fd2323f11ca6765e00e98&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_AddGrowth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=ced236ec7278dcf94d693c9498c9b515fe079c287650de12c54caa455628c6f9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=8c3a7743b1bd8852c12450937f052fc6d5135ce2767fd2323f11ca6765e00e98&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=8c3a7743b1bd8852c12450937f052fc6d5135ce2767fd2323f11ca6765e00e98&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/planet_performance.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=d4bbfba36bc7fdd709f1f0f20eb25bfb96f115da3ff5e1c208fe8316c3c8b3cb&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/DJI_droneRGB.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=5ee247bbd3ebace454c8fc9b914f31c7899f6af278b15519b7324811a6ca3847&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/DJI_drone.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=0996f708e11f2b63d8674610ec9b14b2e496af0d5859b43f13551d94d7792855&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
# https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/TOIS_RGB.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=e7ee0f649c1abfb996244dd79fc673cefe0ec9b100e59fca78b3bc2cee238c53&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/PLanet_WDVI.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=bfe80ce502fec4b9ca71b7761e992709f472abc9320965be515f5ff6401dfacc&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Biomassa</b><br>
#             <small>WDVI</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_CI-Red.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=40aa873c70bfc5b6c791fabb92ed428672571d6008f19716f461f6510ff214af&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Stikstof</b><br>
#             <small>CI-red</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=8c3a7743b1bd8852c12450937f052fc6d5135ce2767fd2323f11ca6765e00e98&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>DSM</b><br>
#             <small>DTM</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/Planet_AddGrowth.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=ced236ec7278dcf94d693c9498c9b515fe079c287650de12c54caa455628c6f9&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Bijgroei</b><br>
#             <small>Add-growth</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=8c3a7743b1bd8852c12450937f052fc6d5135ce2767fd2323f11ca6765e00e98&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>DSM</b><br>
#             <small>DTM</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ahn.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=8c3a7743b1bd8852c12450937f052fc6d5135ce2767fd2323f11ca6765e00e98&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>DTM</b><br>
#             <small>DSM</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/planet_performance.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=d4bbfba36bc7fdd709f1f0f20eb25bfb96f115da3ff5e1c208fe8316c3c8b3cb&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>Prestatie</b><br>
#             <small>Perf</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/DJI_droneRGB.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=5ee247bbd3ebace454c8fc9b914f31c7899f6af278b15519b7324811a6ca3847&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>RGB</b><br>
#             <small>RGB</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/DJI_drone.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=0996f708e11f2b63d8674610ec9b14b2e496af0d5859b43f13551d94d7792855&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>NIR</b><br>
#             <small>NIR</small>
#         </div>
#
#         <div style="display:inline-block; margin:10px; text-align:center;">
#             <img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/TOIS_RGB.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEF7BTWIYQF%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T180838Z&X-Amz-Expires=3600&X-Amz-Signature=e7ee0f649c1abfb996244dd79fc673cefe0ec9b100e59fca78b3bc2cee238c53&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="150"><br>
#             <b>RGB</b><br>
#             <small>RGB</small>
#         </div>

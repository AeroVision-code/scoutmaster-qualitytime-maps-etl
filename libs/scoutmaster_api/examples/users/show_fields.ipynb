# %% [markdown]
# ## Users

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium
import pandas as pd
import geopandas as gpd

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://dev-api.scoutmaster.nl/v2/

# %%
output_folder = "../../data/output/"

# %%
SM_API.output_format = 'df'
df_users = SM_API.users(project_id=project_id)
df_users
# Out:
#                                      id                               user_id  \
# 0  7bda1f61-c503-4d38-bd75-43e838518f99  033448b2-0071-700f-ba76-ac4f39e1c81d
# 1  674fec66-d6a2-45c3-a02f-61c949cd3599  d3d40872-9081-70d6-b546-3beb4b4cc247
# 2  466fee4d-2e3d-46a9-af35-7a865cde08ac  d3c4a822-7051-7060-b45c-06c6b7bffa09
# 3  e7e7ce26-1224-4191-9a2d-2b6bc172945e  73947872-2061-709d-c646-2e561ad7f90d
#
#                              project_id user_role            username  \
# 0  5f88d0d3-e4fc-482d-8981-b3532fa7e2c7     owner  rinusvijftigschild
# 1  5f88d0d3-e4fc-482d-8981-b3532fa7e2c7      user      justintocoding
# 2  5f88d0d3-e4fc-482d-8981-b3532fa7e2c7      user           erikjan22
# 3  5f88d0d3-e4fc-482d-8981-b3532fa7e2c7      user      tammevanderwal
#
#                   name                              email  email_verified  \
# 0  rinus vijftigschild  rinus.vijftigschild@aerovision.nl            True
# 1     Justin Steenhuis          justinsteenhuis@gmail.com            True
# 2         Erik Bootsma         erik.bootsma@aerovision.nl            True
# 3    Tamme van der Wal      tamme.vanderwal@aerovision.nl            True
#
#    phone_number  phone_number_verified     status                created_at  \
# 0  +31621694192                   True  CONFIRMED  2025-07-23T13:53:18.225Z
# 1           NaN                  False  CONFIRMED  2025-03-12T14:46:47.654Z
# 2           NaN                  False  CONFIRMED  2025-07-30T14:03:41.517Z
# 3           NaN                  False  CONFIRMED  2025-07-30T17:00:45.589Z
#
#               last_modified  enabled
# 0  2025-07-23T14:05:22.862Z     True
# 1  2025-09-26T12:39:35.536Z     True
# 2  2025-07-30T14:03:53.457Z     True
# 3  2025-09-30T21:17:37.892Z     True

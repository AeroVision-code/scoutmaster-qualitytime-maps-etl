# %% [markdown]
# ## Fields

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium
import pandas as pd
import geopandas as gpd

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://dev-api.scoutmaster.nl/v2/

# %%
output_folder = "../../data/output/"

# %%
df_projects = SM_API.projects()
df_projects
# Out:
#                                       id                name abbreviation  \
# 0   8574cc2c-857e-477d-8a7d-e14e047adb5e
# 1   6d3359ee-2988-4b23-b35b-14391e0eaa5f  04/06/2025 project           PR
# 2   c52cc8b0-fd2e-4d7b-bc73-9623f8f212ae       Abaco project           AB
# 3   db21b65c-88b0-401f-b7e2-700737e1717a   ChicoGrow project           CH
# 4   282201d8-406a-46f3-91cf-9c5b4031556f         New Project           NP
# 5   227ca66e-3108-4bd2-9b7e-8732c68e90ad               retew           RE
# 6   7916f2f2-aa82-4daf-9db4-16b86386bbfd               sadsa           SA
# 7   13a991ec-2a2c-4cae-878d-df32ce11c54c         sadsasdasda           SA
# 8   48ba0c44-7c95-4fe2-8971-dd04ecfeda73        sadsdsadasda           SA
# 9   ff9548db-3e82-4f59-9995-fdfb010ebb57                SQAT           Sq
# 10  a283dce3-2631-4a9e-be37-fbef710c2e88                test           Te
# 11  a5834420-666b-4bb1-8337-fbb8f0a44d47                test           TE
# 12  e27fa09b-4153-4d0f-8645-92c14aabaee1              test 3          Te3
# 13  5f88d0d3-e4fc-482d-8981-b3532fa7e2c7        Test Project           TE
#
#                                             logo_path
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  https://bioscope-products.s3.eu-central-1.amaz...

# %%
project = df_projects.iloc[13]
project_id = project["id"]
print(project)
# Out:
# id                           5f88d0d3-e4fc-482d-8981-b3532fa7e2c7
# name                                                 Test Project
# abbreviation                                                   TE
# logo_path       https://bioscope-products.s3.eu-central-1.amaz...
# Name: 13, dtype: object

# %%
SM_API.output_format = 'df'
df_fields = SM_API.fields(project_id=project_id)
df_fields
# Out:
#                                      id                        name  \
# 0  39507fbd-6f0e-49e5-bdb2-f36d964cffa1          bieten rombouts 25
# 1  b9355535-57c8-4dc4-98cc-13b211486ae8  jan wolfsven achter koraan
# 2  fb34d37d-baa1-4e8a-a8cd-5a5f60c5e7c3         KNVB zeist - veld 2
# 3  e184e655-494c-4b78-9f61-13a5abee6b98                    Parcel 1
# 4  8e6b77a5-e025-4cb5-947a-efdda17c562e                    Parcel 1
# 5  16b6f480-cf7e-4e82-850e-a34ca30f0498                    Parcel 1
# 6  7e9e8bf1-c782-4d0e-9003-0a392c0ecc55                    Parcel 1
# 7  51a1f1e4-1491-48fa-8468-619ffabac34f                    Parcel 1
# 8  10f08d0c-f1be-4ff3-8aed-556b15dfb61a                     Perceel
# 9  5150a1c3-1a97-4cf7-91d6-73abfba66f06                        test
#
#                                              address    area_ha  \
# 0  {'road': 'Brede Balrouw', 'state': 'Noord-Brab...       3.13
# 1  {'road': 'E34', 'town': 'Mol', 'state': 'Antwe...       6.89
# 2  {'road': 'Woudenbergseweg', 'town': 'Zeist', '...       0.79
# 3  {'road': 'Averlose Houtweg', 'state': 'Overijs...   47187.50
# 4  {'city': 'Buurmalsen', 'road': 'Nieuwe Steeg',...       0.97
# 5  {'road': 'Lange Dreef', 'town': 'Culemborg', '...       1.81
# 6  {'road': 'Amerongerwetering', 'state': 'Utrech...  130713.79
# 7  {'state': 'Noord-Holland', 'hamlet': 'Rozewerf...   49355.15
# 8  {'road': 'Woerdenseweg', 'state': 'Utrecht', '...       3.16
# 9  {'city': 'Almere', 'road': 'Muidergouw', 'stat...       0.76
#
#                                             geometry  \
# 0  POLYGON((4.57549667 51.58900725,4.57435942 51....
# 1  POLYGON((5.153874601445684 51.30599682346048,5...
# 2  POLYGON((5.2931019551254 52.089336855448,5.291...
# 3  POLYGON((5.965393572319225 52.38960832650034,5...
# 4  POLYGON((5.298669390899618 51.909290918712685,...
# 5  POLYGON((5.243629543629972 51.96311634184721,5...
# 6  POLYGON((5.082912468793471 52.137460418811685,...
# 7  POLYGON((4.742155811400783 52.439865938647074,...
# 8  POLYGON((5.014589162438086 52.156113823704914,...
# 9  POLYGON((5.2155 52.3495,5.2165 52.3495,5.2165 ...
#
#                          created_at deleted_at  \
# 0     2025-07-30T13:42:43.496+00:00       None
# 1  2025-01-31T17:10:09.802391+00:00       None
# 2     2025-08-14T12:33:40.256+00:00       None
# 3  2026-01-19T18:29:56.931494+00:00       None
# 4  2026-01-19T18:34:16.663927+00:00       None
# 5   2026-01-19T21:34:02.38306+00:00       None
# 6   2026-01-19T17:38:50.18399+00:00       None
# 7  2026-01-19T18:29:33.398779+00:00       None
# 8   2026-01-19T19:40:29.25314+00:00       None
# 9  2025-11-27T10:17:04.534897+00:00       None
#
#                                       properties  \
# 0  {'description': 'A description of the field'}
# 1                                           None
# 2  {'description': 'A description of the field'}
# 3                            {'description': ''}
# 4                            {'description': ''}
# 5                            {'description': ''}
# 6                            {'description': ''}
# 7                            {'description': ''}
# 8                            {'description': ''}
# 9                                           None
#
#                          updated_at country_code reference_point  \
# 0     2025-07-30T13:42:43.496+00:00         None            None
# 1  2025-01-31T17:10:09.802412+00:00         None            None
# 2     2025-08-14T12:33:40.256+00:00         None            None
# 3  2026-01-19T18:29:56.931494+00:00         None            None
# 4  2026-01-19T18:34:16.663927+00:00         None            None
# 5   2026-01-19T21:34:02.38306+00:00         None            None
# 6   2026-01-19T17:38:50.18399+00:00         None            None
# 7  2026-01-19T18:29:33.398779+00:00         None            None
# 8   2026-01-19T19:40:29.25314+00:00         None            None
# 9  2025-11-27T10:17:04.534897+00:00         None            None
#
#   scoutMaster_reportId
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# 5                 None
# 6                 None
# 7                 None
# 8                 None
# 9                 None

# %%
SM_API.output_format = 'geojson'
geojson_fields = SM_API.fields(project_id)

output_file =  output_folder + 'fields.geojson'
with open(output_file, "w") as f:
    if isinstance(geojson_fields, str):
        f.write(geojson_fields)
    else:
        # If it's a Python dict, convert to JSON first
        json.dump(geojson_fields, f, indent=2)

# %%
SM_API.output_format = 'gdf'
gdf_fields = SM_API.fields(project_id=project_id)
gdf_fields_subset = gdf_fields.iloc[0:10]
for index, row in gdf_fields_subset.iterrows():
    # Select single row as GeoDataFrame
    gdf_field = gdf_fields_subset.loc[[index]]  # double brackets to keep it as GeoDataFrame

    # Get field name from row (replace 'field_name' with the actual column name)
    field_name = row['name']  
    # Plot
    ax = gdf_field.plot(figsize=(6, 6), edgecolor='black', facecolor='lightgreen')
    ax.set_title(f"Field: {field_name}", fontsize=14)
    plt.show()

# %%
gdf_fields
# Out:
#                                             geometry  \
# 0  POLYGON ((4.5755 51.58901, 4.57436 51.58943, 4...
# 1  POLYGON ((5.15387 51.306, 5.15388 51.30604, 5....
# 2  POLYGON ((5.2931 52.08934, 5.292 52.09004, 5.2...
# 3  POLYGON ((5.96539 52.38961, 5.87754 52.27548, ...
# 4  POLYGON ((5.29867 51.90929, 5.29872 51.90964, ...
# 5  POLYGON ((5.24363 51.96312, 5.24482 51.96375, ...
# 6  POLYGON ((5.08291 52.13746, 4.95101 51.77184, ...
# 7  POLYGON ((4.74216 52.43987, 4.72017 52.26539, ...
# 8  POLYGON ((5.01459 52.15611, 5.01445 52.15817, ...
# 9  POLYGON ((5.2155 52.3495, 5.2165 52.3495, 5.21...
#
#                                      id                        name  \
# 0  39507fbd-6f0e-49e5-bdb2-f36d964cffa1          bieten rombouts 25
# 1  b9355535-57c8-4dc4-98cc-13b211486ae8  jan wolfsven achter koraan
# 2  fb34d37d-baa1-4e8a-a8cd-5a5f60c5e7c3         KNVB zeist - veld 2
# 3  e184e655-494c-4b78-9f61-13a5abee6b98                    Parcel 1
# 4  8e6b77a5-e025-4cb5-947a-efdda17c562e                    Parcel 1
# 5  16b6f480-cf7e-4e82-850e-a34ca30f0498                    Parcel 1
# 6  7e9e8bf1-c782-4d0e-9003-0a392c0ecc55                    Parcel 1
# 7  51a1f1e4-1491-48fa-8468-619ffabac34f                    Parcel 1
# 8  10f08d0c-f1be-4ff3-8aed-556b15dfb61a                     Perceel
# 9  5150a1c3-1a97-4cf7-91d6-73abfba66f06                        test
#
#                                              address    area_ha  \
# 0  {'road': 'Brede Balrouw', 'state': 'Noord-Brab...       3.13
# 1  {'road': 'E34', 'town': 'Mol', 'state': 'Antwe...       6.89
# 2  {'road': 'Woudenbergseweg', 'town': 'Zeist', '...       0.79
# 3  {'road': 'Averlose Houtweg', 'state': 'Overijs...   47187.50
# 4  {'city': 'Buurmalsen', 'road': 'Nieuwe Steeg',...       0.97
# 5  {'road': 'Lange Dreef', 'town': 'Culemborg', '...       1.81
# 6  {'road': 'Amerongerwetering', 'state': 'Utrech...  130713.79
# 7  {'state': 'Noord-Holland', 'hamlet': 'Rozewerf...   49355.15
# 8  {'road': 'Woerdenseweg', 'state': 'Utrecht', '...       3.16
# 9  {'city': 'Almere', 'road': 'Muidergouw', 'stat...       0.76
#
#                          created_at deleted_at  \
# 0     2025-07-30T13:42:43.496+00:00       None
# 1  2025-01-31T17:10:09.802391+00:00       None
# 2     2025-08-14T12:33:40.256+00:00       None
# 3  2026-01-19T18:29:56.931494+00:00       None
# 4  2026-01-19T18:34:16.663927+00:00       None
# 5   2026-01-19T21:34:02.38306+00:00       None
# 6   2026-01-19T17:38:50.18399+00:00       None
# 7  2026-01-19T18:29:33.398779+00:00       None
# 8   2026-01-19T19:40:29.25314+00:00       None
# 9  2025-11-27T10:17:04.534897+00:00       None
#
#                                       properties  \
# 0  {'description': 'A description of the field'}
# 1                                           None
# 2  {'description': 'A description of the field'}
# 3                            {'description': ''}
# 4                            {'description': ''}
# 5                            {'description': ''}
# 6                            {'description': ''}
# 7                            {'description': ''}
# 8                            {'description': ''}
# 9                                           None
#
#                          updated_at country_code reference_point  \
# 0     2025-07-30T13:42:43.496+00:00         None            None
# 1  2025-01-31T17:10:09.802412+00:00         None            None
# 2     2025-08-14T12:33:40.256+00:00         None            None
# 3  2026-01-19T18:29:56.931494+00:00         None            None
# 4  2026-01-19T18:34:16.663927+00:00         None            None
# 5   2026-01-19T21:34:02.38306+00:00         None            None
# 6   2026-01-19T17:38:50.18399+00:00         None            None
# 7  2026-01-19T18:29:33.398779+00:00         None            None
# 8   2026-01-19T19:40:29.25314+00:00         None            None
# 9  2025-11-27T10:17:04.534897+00:00         None            None
#
#   scoutMaster_reportId
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# 5                 None
# 6                 None
# 7                 None
# 8                 None
# 9                 None

# %%
# Convert 'created_at' to datetime
gdf_fields = gdf_fields.copy()
gdf_fields["created_at"] = pd.to_datetime(
    "2025-06-16T16:54:23.294+00:00", utc=True
)

# Reproject to metric CRS for calculations
gdf_proj = gdf_fields.to_crs(epsg=3857)

# Compute centroid in projected CRS
centroid_proj = gdf_proj.geometry.centroid.unary_union.centroid

# Transform centroid back to WGS84 for folium
centroid = gpd.GeoSeries([centroid_proj], crs=gdf_proj.crs).to_crs(epsg=4326).iloc[0]

# Transform geometries back to WGS84 for display
gdf_wgs = gdf_proj.to_crs(epsg=4326)

# Compute map bounds
total_bounds = gdf_wgs.total_bounds
sw = [total_bounds[1], total_bounds[0]]
ne = [total_bounds[3], total_bounds[2]]

# Create folium map with Esri imagery
m = folium.Map(
    location=[centroid.y, centroid.x],
    tiles="Esri.WorldImagery",
    attr="Esri"
)

m.fit_bounds([sw, ne])

# Add polygons
for idx, row in gdf_wgs.iterrows():
    popup_text = "<b>Field Details</b><br>"
    for col in gdf_wgs.columns:
        if col != "geometry":
            popup_text += f"<b>{col}:</b> {row[col]}<br>"
        
    folium.GeoJson(
        row.geometry,
        name=str(idx),
        popup=folium.Popup(popup_text, max_width=400)
    ).add_to(m)

display(m)
# Out:
# C:\Users\Rinus\AppData\Local\Temp\ipykernel_8080\1696706695.py:11: DeprecationWarning: The 'unary_union' attribute is deprecated, use the 'union_all()' method instead.
#   centroid_proj = gdf_proj.geometry.centroid.unary_union.centroid
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e8b5e8ac9b40be70e1b6ab7b81b2ba1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e8b5e8ac9b40be70e1b6ab7b81b2ba1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e8b5e8ac9b40be70e1b6ab7b81b2ba1 = L.map(
#                 &quot;map_2e8b5e8ac9b40be70e1b6ab7b81b2ba1&quot;,
#                 {
#                     center: [52.017703193015265, 5.224229932727997],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af387217a043ce435e7e3a2a339ec06d = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Esri&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af387217a043ce435e7e3a2a339ec06d.addTo(map_2e8b5e8ac9b40be70e1b6ab7b81b2ba1);
#
#
#             map_2e8b5e8ac9b40be70e1b6ab7b81b2ba1.fitBounds(
#                 [[51.30358587300001, 4.5742682199999996], [52.62764035499999, 6.508996876]],
#                 {}
#             );
#
#
#
#         function geo_json_34b63b8698f8d2be92155cf3896e85e3_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_34b63b8698f8d2be92155cf3896e85e3 = L.geoJson(null, {
#                 onEachFeature: geo_json_34b63b8698f8d2be92155cf3896e85e3_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_34b63b8698f8d2be92155cf3896e85e3_add (data) {
#             geo_json_34b63b8698f8d2be92155cf3896e85e3
#                 .addData(data);
#         }
#             geo_json_34b63b8698f8d2be92155cf3896e85e3_add({&quot;coordinates&quot;: [[[4.57549667, 51.589007249999995], [4.57435942, 51.58943385999999], [4.5742682199999996, 51.589457190000005], [4.57428446, 51.58949512000001], [4.57487396, 51.59010121999999], [4.575445, 51.59068571000001], [4.5766418700000004, 51.59190861999999], [4.57674372, 51.59201086], [4.57687035, 51.59174288999999], [4.577100879999999, 51.5912525], [4.57716987, 51.59117347], [4.577246940000001, 51.59110843999999], [4.57751072, 51.590937610000005], [4.577495169999999, 51.590918390000006], [4.57698386, 51.59037507999999], [4.57646568, 51.58981891], [4.57579688, 51.58912930000001], [4.57563615, 51.58896726], [4.57549667, 51.589007249999995]]], &quot;type&quot;: &quot;Polygon&quot;});
#         geo_json_34b63b8698f8d2be92155cf3896e85e3.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#         var popup_4923aacd326c74ae3b63e0149ed8b64e = L.popup({
#   &quot;maxWidth&quot;: 400,
# });
#
#
#
#                 var html_b09d20aca0506c2b2d900e88c9095211 = $(`&lt;div id=&quot;html_b09d20aca0506c2b2d900e88c9095211&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Field Details&lt;/b&gt;&lt;br&gt;&lt;b&gt;id:&lt;/b&gt; 39507fbd-6f0e-49e5-bdb2-f36d964cffa1&lt;br&gt;&lt;b&gt;name:&lt;/b&gt; bieten rombouts 25&lt;br&gt;&lt;b&gt;address:&lt;/b&gt; {&#x27;road&#x27;: &#x27;Brede Balrouw&#x27;, &#x27;state&#x27;: &#x27;Noord-Brabant&#x27;, &#x27;hamlet&#x27;: &#x27;Kruisstraat&#x27;, &#x27;country&#x27;: &#x27;Nederland&#x27;, &#x27;village&#x27;: &#x27;Hoeven&#x27;, &#x27;postcode&#x27;: &#x27;4741 RN&#x27;, &#x27;country_code&#x27;: &#x27;nl&#x27;, &#x27;municipality&#x27;: &#x27;Halderberge&#x27;, &#x27;ISO3166-2-lvl4&#x27;: &#x27;NL-NB&#x27;}&lt;br&gt;&lt;b&gt;area_ha:&lt;/b&gt; 3.13&lt;br&gt;&lt;b&gt;created_at:&lt;/b&gt; 2025-06-16 16:54:23.294000+00:00&lt;br&gt;&lt;b&gt;deleted_at:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;properties:&lt;/b&gt; {&#x27;description&#x27;: &#x27;A description of the field&#x27;}&lt;br&gt;&lt;b&gt;updated_at:&lt;/b&gt; 2025-07-30T13:42:43.496+00:00&lt;br&gt;&lt;b&gt;country_code:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;reference_point:&lt;/b&gt; None&lt;br&gt;&lt;b&gt;scoutMaster_reportId:&lt;/b&gt; None&lt;br&gt;&lt;/div&gt;`)[0];
#                 popup_4923aacd326c74ae3b63e0149ed8b64e.setContent(html_b09d20aca0506c2b2d900e88c9095211);
#
#
#
#         geo_json_34b63b8698f8d2be92155cf3896e85e3.bindPopup(popup_4923aacd326c74ae3b63e0149ed8b64e)
#         ;
#
#
#
#
#             geo_json_34b63b8698f8d2be92155cf3896e85e3.addTo(map_2e8b5e8ac9b40be70e1b6ab7b81b2ba1);
#
#
#
#         function geo_json_1ef61014c10600398659077d5b97e777_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_1ef61014c10600398659077d5b97e777 = L.geoJson(null, {
#                 onEachFeature: geo_json_1ef61014c10600398659077d5b97e777_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_1ef61014c10600398659077d5b97e777_add (data) {
#             geo_json_1ef61014c10600398659077d5b97e777
#                 .addData(data);
#         }
#             geo_json_1e

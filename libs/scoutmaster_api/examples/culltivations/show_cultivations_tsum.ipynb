# %% [markdown]
# ## Cultivations

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium
import pandas as pd
import geopandas as gpd

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = False

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://api.scoutmaster.nl/v2/

# %%
output_folder = "../../data/output/"

# %%
SM_API.output_format = 'df'
df_cultivations = SM_API.cultivations(project_id=project_id)
df_cultivations
# Out:
#      id                              field_id  \
# 0   421  97e962b4-ecb2-44cf-9d53-6354f7342e78
# 1   422  97e96137-e853-4803-9230-7d3039ff4327
# 2   423  97e95b9f-d532-41c3-b727-0817de2b5f95
# 3   424  97e95d45-e191-421d-98af-e6c5a5c3b7c1
# 4   425  97f4842a-1923-4e8a-8119-8456e8f14cb4
# 5   380  97f4841e-03db-4a07-9494-69d96344da08
# 6   381  9e33c0ca-88e6-43c2-ba74-5fce8592f5ce
# 7   382  9e33c40e-0656-4b4a-baef-dd75bd05e116
# 8   383  97f49356-d7f5-46ac-ad18-fbb4f3690d31
# 9   384  97f49d47-106f-48e1-ad9b-07b11def401b
# 10  385  97f49a25-e4c5-4b47-9d48-39e0f1a42c6b
# 11  386  97e924fa-405a-4300-b8ec-3208c3bcdebf
# 12  387  97e93ac3-91b0-40ba-aa03-29b254b9a4a8
# 13  388  97e92c6d-ceb4-4602-b61d-95f91f09afba
# 14  389  97e92989-0baa-477e-a8da-43eb036979d7
# 15  390  97e93506-c727-4221-9b1d-8ee2b7490420
# 16  391  97e93594-5d6c-4501-857d-73b1c5fbddca
# 17  392  97e936c1-e5f5-4887-9d2d-7b755e5c478b
# 18  393  97e954df-6e73-40d3-81a4-a377edcd00a0
# 19  394  97e9429a-570a-40c1-9d7a-0e11540bfc8f
# 20  395  97e94741-dfa5-4ff4-be59-3c03f2f01c53
# 21  396  97f49f49-7ccd-4ab9-b3c8-b7d59ac7185e
# 22  397  97f49ff0-48b7-46a0-b471-fde438566046
# 23  398  97f4a352-c0fd-44c0-83ca-ce256e7c6d7b
# 24  399  97e9382d-0744-410d-bbf5-71f516c5653f
# 25  400  97f49e8f-1f5f-4005-ad81-1dee167622e9
# 26  401  97e93203-1656-448b-97b5-dffd19803c61
# 27  402  97e930ac-15b6-4078-8f19-779ef321c975
# 28  403  97e9281a-e19d-4dc9-a67d-1d9412baa4b5
# 29  404  97f4900c-135b-4b52-b6b2-daf9d5a85879
# 30  405  97f4a614-21b3-4ae7-b03d-705b36cbc094
# 31  406  97e92b19-ea41-48be-9b9b-0851224f486e
# 32  407  97f4a13c-ea24-4b20-ab9d-7702d1f4df28
# 33  408  97f498c9-8626-402b-af30-1d96df7bdde9
# 34  409  97f497d9-3636-4f1d-9348-c90dc080c9bc
# 35  410  97f4a74d-cb5c-4c23-9f2d-d208bc527796
# 36  411  97f4a9e3-ebdd-4f01-ad2c-a42652406438
# 37  412  97f49e0b-20a8-497f-936c-865055c8a5ca
# 38  413  97f4a1f2-67cf-4b37-b6c9-0dcc8c192790
# 39  414  97f4b218-48dc-4fd3-a810-7ec999ac4ff7
# 40  415  97f4b144-8b63-4720-aa9f-be3384c8dfc9
# 41  416  97f4ab56-a0c3-466a-91b9-0b1e09154794
# 42  417  97f4aea9-183b-4b36-b871-d19083027365
# 43  418  97f4abf4-67ab-4589-a8e1-67d3e662c7d2
# 44  419  97f4a847-f749-453e-a0ca-29f3cf0746bf
# 45  420  97e92060-daae-4e10-8b66-414735b7ca72
# 46  426  97f49bce-9b86-4a31-bd54-5462bb690ede
# 47  427  97f49176-3210-45ed-a99c-d9b0afc65744
# 48  428  97e93f4f-84db-4993-885f-6cb148a9a0a6
# 49  429  97f49a25-e4c5-4b47-9d48-39e0f1a42c6b
#
#                                            field_name  \
# 0               48-A7 Spaander Tulp (twee plant data)
# 1                             50-De Weere Lilies Tulp
# 2                          52-De Weere Boerderij Tulp
# 3                            53-2e De Weere Boerderij
# 4                                       54- 2e secret
# 5                                        6- 1e secret
# 6                         02: 1e De Weere Boederij wk
# 7                           06: 1e De Weere Lilies wk
# 8   10-Sijbekarspel Front 2+1 plantdagen, 2e ronde...
# 9                                11-1e Hauwert Garden
# 10                              12-1e Kok | 58-2e Kok
# 11                         13-Nieuwedijk Hetsen front
# 12            14-Koggerandweg Front East (2 zaaidata)
# 13                               15-1e Dirkbijvoetweg
# 14                               12 : 1e Mol Liederik
# 15                                17-Twisk Front East
# 16                      18a-Twisk Front Midden (oost)
# 17                               18b-Twisk Front West
# 18                         19-Wagenpad Rechts Viersen
# 19                                 21-Zuiderdijkweg 1
# 20                           21 : Zuiderdijkweg 1  wk
# 21                              24-Cor Schilder Front
# 22                               25-Cor Schilder Back
# 23                           56 : Horizon Oudijk Tulp
# 24                               26 : Oosterlanderweg
# 25                                28-Church Zwaagdijk
# 26                                29-Brakeweg (noord)
# 27                                 29-Brakeweg (zuid)
# 28                                       11 :  1e COR
# 29                                     31-Cowboy Tulp
# 30                                          32-Carrot
# 31                             34-Dirkbijvoetweg Tulp
# 32            35-Ries Weering (en 04:1e Ries Weering)
# 33         36-Horizon van de Deurenweg (2 plantdagen)
# 34                                    37-Nibbix Sport
# 35                                 38-Stam North Tulp
# 36                39-2e Koos East (en 3-1e Koos East)
# 37                        58 :  2e Tuinstraat Alliums
# 38                            42-2e Wiering Boerderij
# 39             9-1e Blokker Tulp | 44-2e Blokker Tulp
# 40                                    43-Blokker Tulp
# 41                           45A-Wijzenddijkje tulp 1
# 42                           45B-Wijzenddijkje tulp 2
# 43                           45C-Wijzenddijkje tulp 3
# 44                                 46-Stam South Tulp
# 45                         47-Nieuwendijk Hetsen Tulp
# 46                                  55-Hauwert Garden
# 47                          56-Sijbekarspel Back Tulp
# 48                         57-Koggerandweg Front Tulp
# 49                              12-1e Kok | 58-2e Kok
#
#                                                  crop  \
# 0   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 1   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 2   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 3   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 4   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 5   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 6   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 7   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 8   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 9   {'code': 2040206, 'name': 'Broccoli', 'variety...
# 10  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 11  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 12  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 13  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 14  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 15  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 16  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 17  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 18  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 19  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 20  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 21  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 22  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 23  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 24  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 25  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 26  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 27  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 28  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 29  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 30  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 31  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 32  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 33  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 34  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 35  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 36  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 37  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 38  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 39  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 40  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 41  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 42  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 43  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 44  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 45  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 46  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 47  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 48  {'code': 2040206, 'name': 'Broccoli', 'variety...
# 49  {'code': 2040206, 'name': 'Broccoli', 'variety...
#
#                                                events
# 0   {'plant': '2022-07-18T00:00:00.000Z', 'harvest...
# 1   {'plant': '2022-07-22T00:00:00.000Z', 'harvest...
# 2   {'plant': '2022-07-23T00:00:00.000Z', 'harvest...
# 3   {'plant': '2022-07-23T00:00:00.000Z', 'harvest...
# 4   {'plant': '2022-07-25T00:00:00.000Z', 'harvest...
# 5   {'plant': '2022-03-16T00:00:00.000Z', 'harvest...
# 6   {'plant': '2022-03-22T00:00:00.000Z', 'harvest...
# 7   {'plant': '2022-03-24T00:00:00.000Z', 'harvest...
# 8   {'plant': '2022-04-03T00:00:00.000Z', 'harvest...
# 9   {'plant': '2022-04-16T00:00:00.000Z', 'harvest...
# 10  {'plant': '2022-04-18T00:00:00.000Z', 'harvest...
# 11  {'plant': '2022-04-18T00:00:00.000Z', 'harvest...
# 12  {'plant': '2022-04-22T00:00:00.000Z', 'harvest...
# 13  {'plant': '2022-04-29T00:00:00.000Z', 'harvest...
# 14  {'plant': '2022-04-30T00:00:00.000Z', 'harvest...
# 15  {'plant': '2022-05-04T00:00:00.000Z', 'harvest...
# 16  {'plant': '2022-05-05T00:00:00.000Z', 'harvest...
# 17  {'plant': '2022-05-06T00:00:00.000Z', 'harvest...
# 18  {'plant': '2022-05-12T00:00:00.000Z', 'harvest...
# 19  {'plant': '2022-05-17T00:00:00.000Z', 'harvest...
# 20  {'plant': '2022-05-18T00:00:00.000Z', 'harvest...
# 21  {'plant': '2022-05-25T00:00:00.000Z', 'harvest...
# 22  {'plant': '2022-05-25T00:00:00.000Z', 'harvest...
# 23  {'plant': '2022-05-26T00:00:00.000Z', 'harvest...
# 24  {'plant': '2022-06-04T00:00:00.000Z', 'harvest...
# 25  {'plant': '2022-06-11T00:00:00.000Z', 'harvest...
# 26  {'plant': '2022-06-21T00:00:00.000Z', 'harvest...
# 27  {'harvest': '2022-08-24T00:00:00.000Z', 'plant...
# 28  {'plant': '2022-06-18T00:00:00.000Z', 'harvest...
# 29  {'plant': '2022-06-22T00:00:00.000Z', 'harvest...
# 30  {'plant': '2022-06-22T00:00:00.000Z', 'harvest...
# 31  {'plant': '2022-06-30T00:00:00.000Z', 'harvest...
# 32  {'plant': '2022-06-29T00:00:00.000Z', 'harvest...
# 33  {'plant': '2022-06-30T00:00:00.000Z', 'harvest...
# 34  {'plant': '2022-07-05T00:00:00.000Z', 'harvest...
# 35  {'plant': '2022-07-06T00:00:00.000Z', 'harvest...
# 36  {'plant': '2022-07-07T00:00:00.000Z', 'harvest...
# 37  {'plant': '2022-07-09T00:00:00.000Z', 'harvest...
# 38  {'plant': '2022-07-13T00:00:00.000Z', 'harvest...
# 39  {'plant': '2022-07-14T00:00:00.000Z', 'harvest...
# 40  {'plant': '2022-07-15T00:00:00.000Z', 'harvest...
# 41  {'plant': '2022-07-15T00:00:00.000Z', 'harvest...
# 42  {'plant': '2022-07-15T00:00:00.000Z', 'harvest...
# 43  {'plant': '2022-07-15T00:00:00.000Z', 'harvest...
# 44  {'plant': '2022-07-17T00:00:00.000Z', 'harvest...
# 45  {'plant': '2022-07-17T00:00:00.000Z', 'harvest...
# 46  {'plant': '2022-07-26T00:00:00.000Z', 'harvest...
# 47  {'plant': '2022-07-27T00:00:00.000Z', 'harvest...
# 48  {'plant': '2022-07-28T00:00:00.000Z', 'harvest...
# 49  {'plant': '2022-07-30T00:00:00.000Z', 'harvest...

# %%
df_tsum = SM_API.cultivations_tsum(421)
df_tsum
# Out:
#          date  dayDelta   value crop_name  variety_name  \
# 0  2022-07-18         0    0.00  Broccoli  Ras onbekend
# 1  2022-07-19         1   17.15  Broccoli  Ras onbekend
# 2  2022-07-20         2   37.70  Broccoli  Ras onbekend
# 3  2022-07-21         3   55.20  Broccoli  Ras onbekend
# 4  2022-07-22         4   68.25  Broccoli  Ras onbekend
# ..        ...       ...     ...       ...           ...
# 66 2022-09-22        66  893.25  Broccoli  Ras onbekend
# 67 2022-09-23        67  900.65  Broccoli  Ras onbekend
# 68 2022-09-24        68  909.20  Broccoli  Ras onbekend
# 69 2022-09-25        69  918.55  Broccoli  Ras onbekend
# 70 2022-09-26        70  926.55  Broccoli  Ras onbekend
#
#                                 field_id
# 0   97e962b4-ecb2-44cf-9d53-6354f7342e78
# 1   97e962b4-ecb2-44cf-9d53-6354f7342e78
# 2   97e962b4-ecb2-44cf-9d53-6354f7342e78
# 3   97e962b4-ecb2-44cf-9d53-6354f7342e78
# 4   97e962b4-ecb2-44cf-9d53-6354f7342e78
# ..                                   ...
# 66  97e962b4-ecb2-44cf-9d53-6354f7342e78
# 67  97e962b4-ecb2-44cf-9d53-6354f7342e78
# 68  97e962b4-ecb2-44cf-9d53-6354f7342e78
# 69  97e962b4-ecb2-44cf-9d53-6354f7342e78
# 70  97e962b4-ecb2-44cf-9d53-6354f7342e78
#
# [71 rows x 6 columns]

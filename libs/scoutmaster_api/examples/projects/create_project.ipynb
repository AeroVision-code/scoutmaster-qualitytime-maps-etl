# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
user_id = os.getenv("SM_USER_ID")
dev = False

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://api.scoutmaster.nl/v2/

# %%
user_id = "033448b2-0071-700f-ba76-ac4f39e1c81d"
name = "test latest"
abbreviation = "te"

# %%
project = SM_API.project_create(user_id, name, abbreviation)
project_id = project["id"]
# Out:
# {'id': '8a18e7f9-f28c-4bd0-87c7-94776851f171', 'name': 'test latest', 'abbreviation': 'te', 'logo_id': None, 'created_at': '2025-12-09T22:26:41.049Z', 'deleted_at': None, 'updated_at': '2025-12-09T22:26:41.049Z'}

# %%
path_logo =  "./soil_data.svg"
data = SM_API.project_upload_logo(project_id, path_logo)
# Out:
# {'upload_url': 'https://bioscope-products.s3.eu-central-1.amazonaws.com/projects/logo/new/8a18e7f9-f28c-4bd0-87c7-94776851f171.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20251209%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251209T222641Z&X-Amz-Expires=300&X-Amz-Signature=c57aeff69c0f04b56fc2784dbab594ef8951383e666c2176267d7f51362ddd2d&X-Amz-SignedHeaders=host&x-amz-checksum-crc32=AAAAAA%3D%3D&x-amz-sdk-checksum-algorithm=CRC32&x-id=PutObject', 'file_key': 'projects/logo/new/8a18e7f9-f28c-4bd0-87c7-94776851f171.png', 'public_url': 'https://bioscope-products.s3.eu-central-1.amazonaws.com/projects/logo/new/8a18e7f9-f28c-4bd0-87c7-94776851f171.png'}
# Logo uploaded successfully!

# %%
data
# Out:
# {'project_id': '8a18e7f9-f28c-4bd0-87c7-94776851f171',
#  'file_key': 'projects/logo/new/8a18e7f9-f28c-4bd0-87c7-94776851f171.png',
#  'public_url': 'https://bioscope-products.s3.eu-central-1.amazonaws.com/projects/logo/new/8a18e7f9-f28c-4bd0-87c7-94776851f171.png'}

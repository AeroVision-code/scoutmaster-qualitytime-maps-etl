# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import folium

# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
dev= os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)

# %%
df_projects = SM_API.projects()
df_projects
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df_projects = SM_API.projects()
#       2 df_projects
#
# File c:\AeroVision-repo\ScoutMasterAPI-builder\scoutmaster\projects.py:9, in Projects.projects(self)
#       7 try:
#       8     endpoint = "projects/"
# ----> 9     data = self._get(endpoint)
#      10     return self._format_output(data)
#      11 except requests.exceptions.RequestException as e:
#
# File c:\AeroVision-repo\ScoutMasterAPI-builder\scoutmaster\base.py:44, in BaseAPI._get(self, endpoint, params, verbose)
#      42 """Internal GET request helper."""
#      43 try:
# ---> 44     self._check_auth()
#      46     response = requests.get(
#      47         f"{self.host}{endpoint}",
#      48         headers=self._get_headers(),
#      49         params=params  # requests will handle encoding
#      50     )
#      51     response.raise_for_status()
#
# File c:\AeroVision-repo\ScoutMasterAPI-builder\scoutmaster\base.py:35, in BaseAPI._check_auth(self)
#      33 def _check_auth(self):
#      34     if not self.access_token:
# ---> 35         raise Exception("Call authenticate() first")
#
# Exception: Call authenticate() first

# %%
# Create a new column for display
def display_logo_or_abbr(row):
    if row['logo_path']:
        return f'<img src="{row["logo_path"]}" width="200">'
    else:
        return f'<div style="font-weight:bold; font-size:14pt;">{row["abbreviation"]}</div>'

df_projects['display'] = df_projects.apply(display_logo_or_abbr, axis=1)

# Display table with HTML
display(HTML(df_projects[['id', 'name', 'display']].to_html(escape=False, index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>id</th>
#       <th>name</th>
#       <th>display</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>8574cc2c-857e-477d-8a7d-e14e047adb5e</td>
#       <td></td>
#       <td><div style="font-weight:bold; font-size:14pt;"></div></td>
#     </tr>
#     <tr>
#       <td>6d3359ee-2988-4b23-b35b-14391e0eaa5f</td>
#       <td>04/06/2025 project</td>
#       <td><div style="font-weight:bold; font-size:14pt;">PR</div></td>
#     </tr>
#     <tr>
#       <td>c52cc8b0-fd2e-4d7b-bc73-9623f8f212ae</td>
#       <td>Abaco project</td>
#       <td><div style="font-weight:bold; font-size:14pt;">AB</div></td>
#     </tr>
#     <tr>
#       <td>db21b65c-88b0-401f-b7e2-700737e1717a</td>
#       <td>ChicoGrow project</td>
#       <td><div style="font-weight:bold; font-size:14pt;">CH</div></td>
#     </tr>
#     <tr>
#       <td>282201d8-406a-46f3-91cf-9c5b4031556f</td>
#       <td>New Project</td>
#       <td><div style="font-weight:bold; font-size:14pt;">NP</div></td>
#     </tr>
#     <tr>
#       <td>7916f2f2-aa82-4daf-9db4-16b86386bbfd</td>
#       <td>sadsa</td>
#       <td><div style="font-weight:bold; font-size:14pt;">SA</div></td>
#     </tr>
#     <tr>
#       <td>13a991ec-2a2c-4cae-878d-df32ce11c54c</td>
#       <td>sadsasdasda</td>
#       <td><div style="font-weight:bold; font-size:14pt;">SA</div></td>
#     </tr>
#     <tr>
#       <td>48ba0c44-7c95-4fe2-8971-dd04ecfeda73</td>
#       <td>sadsdsadasda</td>
#       <td><div style="font-weight:bold; font-size:14pt;">SA</div></td>
#     </tr>
#     <tr>
#       <td>ff9548db-3e82-4f59-9995-fdfb010ebb57</td>
#       <td>SQAT</td>
#       <td><div style="font-weight:bold; font-size:14pt;">Sq</div></td>
#     </tr>
#     <tr>
#       <td>a283dce3-2631-4a9e-be37-fbef710c2e88</td>
#       <td>test</td>
#       <td><div style="font-weight:bold; font-size:14pt;">Te</div></td>
#     </tr>
#     <tr>
#       <td>a5834420-666b-4bb1-8337-fbb8f0a44d47</td>
#       <td>test</td>
#       <td><div style="font-weight:bold; font-size:14pt;">TE</div></td>
#     </tr>
#     <tr>
#       <td>e27fa09b-4153-4d0f-8645-92c14aabaee1</td>
#       <td>test 3</td>
#       <td><div style="font-weight:bold; font-size:14pt;">Te3</div></td>
#     </tr>
#     <tr>
#       <td>5f88d0d3-e4fc-482d-8981-b3532fa7e2c7</td>
#       <td>Test Project</td>
#       <td><img src="https://bioscope-products.s3.eu-central-1.amazonaws.com/preview/ndvi.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIA6GAECDEFR5LCRTP2%2F20260114%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20260114T165814Z&X-Amz-Expires=3600&X-Amz-Signature=7209524d918bbb8a16432bedf56a17bd2d93970506d0041faab94f01294780c4&X-Amz-SignedHeaders=host&x-amz-checksum-mode=ENABLED&x-id=GetObject" width="200"></td>
#     </tr>
#   </tbody>
# </table>

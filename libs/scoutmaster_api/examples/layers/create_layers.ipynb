# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from datetime import datetime
from urllib.parse import urlparse
from pathlib import Path

import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import pandas as pd


# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://dev-api.scoutmaster.nl/v2/

# %%
upload_info = SM_API.layers_uploadurl(
    field_id="b9c9f14e-fbb3-4e16-b90e-5a3b14ffb7e7",
    layer_type_id="a1b2c3d4-e5f6-7890-abcd-1234567890ef",
    acquired_at="2025-11-21T10:15:30Z"
) 

print(upload_info["upload_url"])
# Out:
# https://bioscope-products.s3.eu-central-1.amazonaws.com/layers/new/b9c9f14e-fbb3-4e16-b90e-5a3b14ffb7e7_a1b2c3d4-e5f6-7890-abcd-1234567890ef_20251121T101530.geojson?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=ASIA6GAECDEFTJNIAMPT%2F20251125%2Feu-central-1%2Fs3%2Faws4_request&X-Amz-Date=20251125T202037Z&X-Amz-Expires=300&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEKv%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaDGV1LWNlbnRyYWwtMSJIMEYCIQDVSfobNEItupTCJJNneJGyFy52CnMXXbEiqo367n8LvAIhAIzDpHgNANSW4Dlwo6%2BeBP4czEuEu3NODKoX9Kft%2B%2BKyKsYFCHQQABoMOTc0OTY2MTAyMjgzIgw7Sj6fQi79SvU7WZYqowWY64S3Z%2FLaDMPNv%2FQB1%2FNDRnp03Hr0vKqrpSDS4eS6kD0uFLunEzA1rrA8i8D2cgQ3kTnJQLc6OnUchqcoOuEVnHZBxL4u6cAUwE4AAX2NIYNc8PsRwdh3gY%2BjQRniJcqywr8YDkaS%2B283Ns2t7Ts4fHoh6aI73b70bJ%2Bo%2B7TeIcdtkkV7X%2BOrXzrY7lYzJLcAKMnyR4PW1SN5OBv0ifOckhynFoOt6KuOyrgeujvE41B6lLPrnxddur0BQm2Sjz2UBXPdoXce%2FONhnzsjfc80XaQX%2B5ccWtphQTQjoCbqt9ZfrL3BjYtWl%2FwCNoMyrgAgMAkzGhIEJOMfd2KZtamLaZjLsS4UOiGsmDznXAhgkvl9a%2BnPYFL0jF0YgmLCmCBxxL1unUkJG90nGDZO%2FhEBcwyFdLROrzE9dcrRmBsQt7qlEoHYT1P2jvfE8EILA9DUpGNDGMQiKdwrVg%2BSAEA1DyYu43P4b7XzhN27WfiPOWfUrpaBf%2BnQ3Updhx2MSI4JW8bYLmpGdJAalJB9VWloJzG7tdVg1Uee7Jd308QCr2EQmTl7dOLf17xshLePjXdSulTBBvd9JZSJlcDtT4jSsegFbL01yEl7%2FdZ4E0rPDTm%2FCvtj2s%2FzTv6WbnSMx4lbadRSlEBF6SOMShSC%2FGaoxk4Hl4SeTE1I1Rqf8ZCiM4VtwR749dKcuwKduukzmMgXQab8rtJrH4s6aJSoD5rzASIeDathIVkLRjWXkcok7Kzar3ef5zlY8I51NP4nPT0UjENCQTJaja%2B6Ayh5kj3hQGv1ARz89gtr8NHaQnUuhRr6oIoijoKJTvhn93QfLL10f9tG9igkYw5oOBouic78DLcAreuNq4SEyNgnDln7JzkalgiuUsnnTaNwc1AFgwy5CSUwoP%2BXyQY6sAEsXGaXYXuOADSVMk0Yho6naiTh4Tq3R%2Bq%2B8I3UiQTjHoK5wO67cTvXruciHzaDRBvzfK7O6r01eZCx3VpUuPDaJqhRGdehWjLHUQTr1xOhpfU6ndl42QJnrjP3jV7Sx%2BFV6jpoB0%2FWH3oTs6qJHytnuM%2BQF4yGcIZJ%2B4Yc3nmGaVyweH3qhlyoOHGnW3gJMlpI%2B1tXBs0UIIqb%2BJnGYpoviVTcarfgTd4kDgxuSewekQ%3D%3D&X-Amz-Signature=76b04c49e0d01d45116a11ec880dcad240ea80cde7ae033426d18a4398a52353&X-Amz-SignedHeaders=host&x-amz-checksum-crc32=AAAAAA%3D%3D&x-amz-sdk-checksum-algorithm=CRC32&x-id=PutObject

# %%
SM_API.upload_file()

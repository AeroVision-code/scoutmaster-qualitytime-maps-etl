# %% [markdown]
# ## Layers

# %%
# import packages
import sys
import os
from dotenv import load_dotenv
from IPython.display import display, HTML
import json
import matplotlib.pyplot as plt
import pandas as pd
import geopandas as gpd
from datetime import datetime
from urllib.parse import urlparse
from pathlib import Path

import rasterio
from rasterio.plot import show
import matplotlib.pyplot as plt
import pandas as pd


# Load environment variables from .env file
load_dotenv()

# import the API builder
sys.path.append(os.path.abspath("../../"))
from scoutmaster.api import ScoutMasterAPI

# %%
# Scoutmaster API - Credentials
client_id = os.getenv('SM_CLIENT_ID')
client_secret = os.getenv('SM_CLIENT_SECRET')
project_id = os.getenv('SM_PROJECT_ID')
dev = os.getenv("DEV")

# Scoutmaster API - Init
SM_API = ScoutMasterAPI(dev)
SM_API.authenticate(client_id=client_id, client_secret=client_secret)
# Out:
# ✅ Successfully authenticated ScoutMaster API
# HOST: https://dev-api.scoutmaster.nl/v2/

# %%
df_fields = SM_API.fields(project_id)
df_fields
# Out:
#                                      id                 name  \
# 0  39507fbd-6f0e-49e5-bdb2-f36d964cffa1   bieten rombouts 25
# 1  fb34d37d-baa1-4e8a-a8cd-5a5f60c5e7c3  KNVB zeist - veld 2
#
#                                              address  area_ha  \
# 0  {'road': 'Brede Balrouw', 'state': 'Noord-Brab...     3.13
# 1  {'road': 'Woudenbergseweg', 'town': 'Zeist', '...     0.79
#
#                                             geometry  \
# 0  POLYGON((4.57549667 51.58900725,4.57435942 51....
# 1  POLYGON((5.2931019551254 52.089336855448,5.291...
#
#                       created_at deleted_at  \
# 0  2025-07-30T13:42:43.496+00:00       None
# 1  2025-08-14T12:33:40.256+00:00       None
#
#                                       properties  \
# 0  {'description': 'A description of the field'}
# 1  {'description': 'A description of the field'}
#
#                       updated_at country_code reference_point
# 0  2025-07-30T13:42:43.496+00:00         None            None
# 1  2025-08-14T12:33:40.256+00:00         None            None

# %%
df_layer_types = SM_API.layer_types()
df_layer_types
# Out:
#                                       id                 name    type  \
# 0   0685e79a-d5ca-43f8-a634-6068bdbacfab             Biomassa   index
# 1   204ad08c-0172-442a-9c15-79f09167b605                  RGB     rgb
# 2   0a0e0317-8dad-4118-8150-f7a29732cd65             Scouting  vector
# 3   02efea93-d770-4d86-b22c-0d9a451a276a                    R    band
# 4   4a45fbe2-b6ab-4e29-b658-b1e69d39ac00                    G    band
# 5   4eedc862-e816-42cf-8e04-a21a0c40c73c                    B    band
# 6   1afbec0c-fc04-4edf-a68d-9a0a6e0ecca0          SoilZones 5  vector
# 7   d502f286-4e49-4bcc-a921-8d98c4da146c          SoilZones 3  vector
# 8   51c039a3-865c-42d9-bca8-2d94081d9108          SoilZones 4  vector
# 9   502ff6f2-d14a-4e4d-a54c-ba14b1f84387             Stikstof   index
# 10  d7ba4f2e-38b9-4fe2-a598-d552b8327c0b               Hoogte    band
# 11  84cfe0b4-b802-4f90-bbf2-e8ad455a277a                OSAVI   index
# 12  a0e5516b-2f3a-4286-a715-f2ab0db424c1            Thermisch    band
# 13  aa07ab0f-7ea4-4736-8701-75640ca1830c      Excess of Green   index
# 14  5ceeaabc-fc63-46ca-919c-217c4cc3f222                  Red    band
# 15  4dc60a8a-ae7c-4e69-a6c2-4ecc35132174  Soil Organic Carbon   index
# 16  4c542e73-1e04-4889-ac20-e183cac51ff0    Additional growth   index
# 17  04286de6-120c-46bd-b496-671fe65079fc                  NIR    band
# 18  96579735-bb82-4dec-a407-a623f564fe91                Green    band
# 19  2123bd92-9e6f-4bcd-b524-b30cae19d975                  RGB     rgb
# 20  3a986cf4-7db7-4a0d-9bf4-26c71e351ae2            Prestatie   index
# 21  7a6949bf-3d1e-4c03-8c36-b73c05e12dea                 Clay   index
# 22  48d9e1a4-8285-4418-bb56-414a517e20a4               CI-red   index
# 23  1f6d9860-6516-434d-b482-79db5db28b84                  Red    band
# 24  bb705681-7d7e-42fc-9bbc-c3345594e280                  CVI   index
# 25  13be9851-8133-4b7c-b9ea-1a38683224ba                  DSM    band
# 26  c393fcda-7122-49cc-9fb7-28068e11de72                 WDVI   index
# 27  a5b7fb58-2de7-4433-87f1-9a79a2fec8da                  TVI   index
# 28  21500ea3-c736-487c-abb4-1a20a853cd69                 WDVI   index
# 29  86a531ed-1521-4166-9163-a1df017b0510              RedEdge    band
# 30  00fc9a84-3397-4c10-b5fe-5935d4c37ebb                 NDVI   index
# 31  b8e4f80b-5e5f-4fcf-8fd4-85d28eb11fed                Green    band
# 32  3f298734-a3d0-4e54-b0b3-2d2ae1e7ce6e            SoilZones   index
# 33  59c60267-b56b-425c-83e7-2a5ecfc40bfb                 NDVI   index
# 34  00181570-6935-41db-902b-a65052d8b8bb                Green    band
# 35  f8482d7f-7d48-4655-9de5-7b1c92760166                  RGB     rgb
# 36  a976faf7-fb95-40c2-a7fe-973242e5aead            SoilZones   index
# 37  4d787c38-1bc0-4948-864e-684f7d291bcd                  NIR    band
# 38  9fa20d5b-e46f-424f-b16f-0200bea8c510             Bijgroei   index
# 39  389b682a-facc-467b-a387-e75b6679b7af     Normalized Green   index
# 40  a6539b1f-455d-480e-b4f9-f33ac7e15e2d  Soil Organic Matter    band
# 41  e86e7b7b-444c-4921-9835-9b7e13846567                 NDRE   index
# 42  adbd41e6-6442-4ab7-961e-41e46556e118            Prestatie   index
#
#    abbreviation            group_name  \
# 0          WDVI             soilzones
# 1           RGB             soilzones
# 2         SCOUT  Vegetation maps (HD)
# 3             R             soilzones
# 4             G             soilzones
# 5             B             soilzones
# 6         ZONES             soilzones
# 7         ZONES             soilzones
# 8         ZONES             soilzones
# 9        CI-red  Vegetation maps (HD)
# 10          DTM             soilzones
# 11         None             soilzones
# 12            T             soilzones
# 13          ExG             soilzones
# 14            R             soilzones
# 15        C-org             soilzones
# 16   Add-growth  Vegetation maps (HD)
# 17          NIR             soilzones
# 18            G             soilzones
# 19          RGB             soilzones
# 20         Perf             soilzones
# 21         Clay             soilzones
# 22       CI-red             soilzones
# 23            R             soilzones
# 24         None             soilzones
# 25          DSM             soilzones
# 26         WDVI             soilzones
# 27          TVI             soilzones
# 28         WDVI             soilzones
# 29           RE             soilzones
# 30         None             soilzones
# 31            G             soilzones
# 32        ZONES             soilzones
# 33         NDVI             soilzones
# 34            G             soilzones
# 35          RGB             soilzones
# 36        ZONES             soilzones
# 37          NIR             soilzones
# 38   Add-growth             soilzones
# 39           NG             soilzones
# 40          SOM             soilzones
# 41         None             soilzones
# 42         Perf             soilzones
#
#                                          layer_source  \
# 0   {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 1   {'id': '8a5b0bc3-8e02-4112-a4a8-b05833a3a999',...
# 2   {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 3   {'id': '8a5b0bc3-8e02-4112-a4a8-b05833a3a999',...
# 4   {'id': '8a5b0bc3-8e02-4112-a4a8-b05833a3a999',...
# 5   {'id': '8a5b0bc3-8e02-4112-a4a8-b05833a3a999',...
# 6   {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 7   {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 8   {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 9   {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 10  {'id': '7dfe647f-3caa-4146-8ef3-dcfb5b87a634',...
# 11  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
# 12  {'id': '50d49537-bb6c-4528-bd2a-797538bc5c5b',...
# 13  {'id': '8a5b0bc3-8e02-4112-a4a8-b05833a3a999',...
# 14  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
# 15  {'id': '1704cd10-0fa1-419f-833b-baced87ae57a',...
# 16  {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 17  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
# 18  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
# 19  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 20  {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 21  {'id': '1704cd10-0fa1-419f-833b-baced87ae57a',...
# 22  {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 23  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 24  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 25  {'id': '7dfe647f-3caa-4146-8ef3-dcfb5b87a634',...
# 26  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 27  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 28  {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 29  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
# 30  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
# 31  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 32  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 33  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 34  {'id': '8add465b-4cde-4a84-bdad-d70e701b18f5',...
# 35  {'id': '8add465b-4cde-4a84-bdad-d70e701b18f5',...
# 36  {'id': '9fba7dd8-7fac-477f-88bb-f2b6b5bd93a9',...
# 37  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 38  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
# 39  {'id': '0614ed5a-d776-472b-a8a7-5134559c09a9',...
# 40  {'id': '1704cd10-0fa1-419f-833b-baced87ae57a',...
# 41  {'id': 'f63bd2ec-3c77-4b84-a103-268672375328',...
# 42  {'id': 'f33a1b97-cad2-4f3d-a092-187bb8071fa1',...
#
#                                         preview_image
# 0   https://bioscope-products.s3.eu-central-1.amaz...
# 1   https://bioscope-products.s3.eu-central-1.amaz...
# 2   https://bioscope-products.s3.eu-central-1.amaz...
# 3   https://bioscope-products.s3.eu-central-1.amaz...
# 4   https://bioscope-products.s3.eu-central-1.amaz...
# 5   https://bioscope-products.s3.eu-central-1.amaz...
# 6   https://bioscope-products.s3.eu-central-1.amaz...
# 7   https://bioscope-products.s3.eu-central-1.amaz...
# 8   https://bioscope-products.s3.eu-central-1.amaz...
# 9   https://bioscope-products.s3.eu-central-1.amaz...
# 10  https://bioscope-products.s3.eu-central-1.amaz...
# 11  https://bioscope-products.s3.eu-central-1.amaz...
# 12  https://bioscope-products.s3.eu-central-1.amaz...
# 13  https://bioscope-products.s3.eu-central-1.amaz...
# 14  https://bioscope-products.s3.eu-central-1.amaz...
# 15  https://bioscope-products.s3.eu-central-1.amaz...
# 16  https://bioscope-products.s3.eu-central-1.amaz...
# 17  https://bioscope-products.s3.eu-central-1.amaz...
# 18  https://bioscope-products.s3.eu-central-1.amaz...
# 19  https://bioscope-products.s3.eu-central-1.amaz...
# 20  https://bioscope-products.s3.eu-central-1.amaz...
# 21  https://bioscope-products.s3.eu-central-1.amaz...
# 22  https://bioscope-products.s3.eu-central-1.amaz...
# 23  https://bioscope-products.s3.eu-central-1.amaz...
# 24  https://bioscope-products.s3.eu-central-1.amaz...
# 25  https://bioscope-products.s3.eu-central-1.amaz...
# 26  https://bioscope-products.s3.eu-central-1.amaz...
# 27  https://bioscope-products.s3.eu-central-1.amaz...
# 28  https://bioscope-products.s3.eu-central-1.amaz...
# 29  https://bioscope-products.s3.eu-central-1.amaz...
# 30  https://bioscope-products.s3.eu-central-1.amaz...
# 31  https://bioscope-products.s3.eu-central-1.amaz...
# 32  https://bioscope-products.s3.eu-central-1.amaz...
# 33  https://bioscope-products.s3.eu-central-1.amaz...
# 34  https://bioscope-products.s3.eu-central-1.amaz...
# 35  https://bioscope-products.s3.eu-central-1.amaz...
# 36  https://bioscope-products.s3.eu-central-1.amaz...
# 37  https://bioscope-products.s3.eu-central-1.amaz...
# 38  https://bioscope-products.s3.eu-central-1.amaz...
# 39  https://bioscope-products.s3.eu-central-1.amaz...
# 40  https://bioscope-products.s3.eu-central-1.amaz...
# 41  https://bioscope-products.s3.eu-central-1.amaz...
# 42  https://bioscope-products.s3.eu-central-1.amaz...

# %%
layer_type = df_layer_types.iloc[0]
layer_type_id = layer_type["id"]

field = df_fields.iloc[0]
field_id = field["id"]

# %%
print("FIELD:", field["name"], "ID:", field["id"])
print("LAYERTYPE:", layer_type["name"], "ID:", layer_type_id)
# Out:
# FIELD: bieten rombouts 25 ID: 39507fbd-6f0e-49e5-bdb2-f36d964cffa1
# LAYERTYPE: Biomassa ID: 0685e79a-d5ca-43f8-a634-6068bdbacfab

# %%
df_layers = SM_API.layers(field_id, layer_type_id)
df_layers 
# df_layers["updated_at"] = pd.to_datetime(df_layers["updated_at"], utc=True, errors="coerce")

# # Define 'today' in UTC
# today = pd.Timestamp(datetime.now().date()).tz_localize("UTC")

# # Filter rows where updated_at is today or later
# df_layers_today = df_layers[df_layers["updated_at"] >= today]
# df_layers_today
# Out:
#     id  layer_stack_id                created_at layer_crs  \
# 0  821            1124  2025-09-02T14:07:40.831Z      None
#
#                  updated_at  \
# 0  2025-09-02T14:07:40.831Z
#
#                                                 path  \
# 0  https://soildata-terrasphere.s3.eu-central-1.a...
#
#                 acquired_at           layer_timestamp  \
# 0  2025-07-24T10:02:00.000Z  2025-07-24T10:02:00.000Z
#
#                                           layer_type  \
# 0  {'id': '0685e79a-d5ca-43f8-a634-6068bdbacfab',...
#
#                                     layer_statistics
# 0  {'min': 0.02903999947011471, 'UCL_95': 0.10199...

# %% [markdown]
# ### plot vectors

# %%
dn_colors = {1: "#D1F2FF", 2: "#FF4700", 3: "#8ED547"}
for idx, row in df_layers.iterrows():
    file_path = row["path"]
    layer_type_name = row['layer_type']['name']
    parsed = urlparse(file_path)
    # Use the path part only
    extension = Path(parsed.path).suffix.lower().replace(".", "")
    if extension == "geojson":
        try:
            # Read GeoJSON
            gdf = gpd.read_file(file_path)
            
            # Optional: color by DN if the property exists
            if "DN" in gdf.columns:
                gdf["plot_color"] = gdf["DN"].map(dn_colors)
            else:
                gdf["plot_color"] = "#AAAAAA"  # fallback gray

            # Plot
            gdf.plot(color=gdf["plot_color"], edgecolor="black", alpha=0.7)
            plt.title(str(row.get("acquired_at", f"Layer {idx}")))
            plt.axis("equal")  # maintain aspect ratio
            plt.show()

        except Exception as e:
            print(f"⚠️ Failed to plot {file_path}: {e}")
    elif extension == "tif" or extension == "tiff":
        # Open the GeoTIFF directly from URL
        with rasterio.open(file_path) as src:
            print(src.nodata)
            fig, ax = plt.subplots(figsize=(8, 6))
            show(src, ax=ax, cmap='viridis')
            ax.set_title(f"Layer ID: {row['id']} - {layer_type_name}")
            plt.show()
# Out:
# -1.0
